# %% [markdown]
# # `indexPrice`
#
# - `KRX_KOSPI200_indexPrice`
#   - 개요
#     - 2011-01-03~2018-12-31
#     - KRX KOSPI200 지수 가격 데이터
#   - Data Source
#     - [KRX_정보데이터시스템](http://data.krx.co.kr/contents/MDC/MDI/mdiLoader/index.cmd?menuId=MDC0201010105)
# - `KRX_KOSPI200ESG_indexPrice`
#   - 개요
#     - 2012-01-03~2022-09-30
#       - 2011/01/03 부터 조회하였으나 2011년 데이터 없음.
#     - KRX KOSPI200ESG 지수 가격 데이터
#   - Data Source
#     - [KRX_정보데이터시스템](http://data.krx.co.kr/contents/MDC/MDI/mdiLoader/index.cmd?menuId=MDC0201010105&idxCd=1&idxCd2=180)

# %% [markdown]
# # import

# %%
import sys
import time
from glob import glob

import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup as bs

from tqdm import tqdm

sys.path.append("../import")
import module as m

pd.options.display.max_columns = None

data_path = m.data_path

# kip : Kospi 200 stock Index Price
fp_kip = f"{data_path}KRX_KOSPI200_indexPrice_raw.csv"
# keip : Kospi 200 Esg stock Index Price
fp_keip = f"{data_path}KRX_KOSPI200ESG_indexPrice_raw.csv"
# ip : Index Price merge axis=0
fp_ip0 = f"""{data_path}indexPrice0.parquet'"""
# ip : Index Price merge axis=1
fp_ip1 = f"""{m.fp["indexPrice"]}"""
# Out:
# data_path : ../data/
# fp
# {'esgRating': '../data/esgRating.parquet',
#  'finaStat': '../data/finaStat.parquet',
#  'indexPrice': '../data/indexPrice.parquet',
#  'stockPrice': '../data/stockPrice.parquet'}

# %% [markdown]
# # `indexPrice`

# %% [markdown]
# ## DataLoad

# %%
df_kip = m.DataLoad(fp_kip)
# Out:
# Mem. usage decreased to  0.07 Mb (60.0% reduction)
#
#
# ┌▣ df.shape ---- ---- ---- ----
# (2220, 10)
#
#
# ┌▣ df.info() ---- ---- ---- ----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2220 entries, 0 to 2219
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일자      2220 non-null   object
#  1   종가      2220 non-null   float16
#  2   대비      2220 non-null   float16
#  3   등락률     2220 non-null   float16
#  4   시가      2220 non-null   float16
#  5   고가      2220 non-null   float16
#  6   저가      2220 non-null   float16
#  7   거래량     2220 non-null   float32
#  8   거래대금    2220 non-null   float32
#  9   상장시가총액  2220 non-null   float32
# dtypes: float16(6), float32(3), object(1)
# memory usage: 69.5+ KB
# None
#
#
# ┌▣ df.head() ---- ---- ---- ----
#            일자     종가        대비       등락률      시가      고가      저가      거래량  \
# 0  2018/12/28  262.0  1.410156  0.540039  261.50  262.75  261.25  62701.0
# 1  2018/12/27  260.5 -0.409912 -0.160034  261.50  261.75  259.75  84457.0
# 2  2018/12/26  261.0 -3.470703 -1.309570  261.00  262.50  259.25  92493.0
# 3  2018/12/24  264.5 -0.609863 -0.229980  263.50  265.00  263.00  61962.0
# 4  2018/12/21  265.0  0.250000  0.090027  263.75  265.00  263.25  92600.0
#
#         거래대금        상장시가총액
# 0  2895636.0  1.165450e+09
# 1  4081822.0  1.158683e+09
# 2  4372646.0  1.161841e+09
# 3  2930704.0  1.176009e+09
# 4  4430738.0  1.179096e+09
# ┌▣ df.columns.to_list() ---- ---- ---- ----
# ['일자', '종가', '대비', '등락률', '시가', '고가', '저가', '거래량', '거래대금', '상장시가총액']

# %%
df_keip = m.DataLoad(fp_keip)
# Out:
# Mem. usage decreased to  0.05 Mb (59.9% reduction)
#
#
# ┌▣ df.shape ---- ---- ---- ----
# (1721, 10)
#
#
# ┌▣ df.info() ---- ---- ---- ----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1721 entries, 0 to 1720
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일자      1721 non-null   object
#  1   종가      1721 non-null   float16
#  2   대비      1720 non-null   float16
#  3   등락률     1720 non-null   float16
#  4   시가      4 non-null      float16
#  5   고가      4 non-null      float16
#  6   저가      4 non-null      float16
#  7   거래량     4 non-null      float32
#  8   거래대금    4 non-null      float32
#  9   상장시가총액  4 non-null      float32
# dtypes: float16(6), float32(3), object(1)
# memory usage: 53.9+ KB
# None
#
#
# ┌▣ df.head() ---- ---- ---- ----
#            일자      종가        대비       등락률      시가      고가      저가      거래량  \
# 0  2018/12/28  272.75  1.589844  0.589844  272.25  273.75  272.00  48040.0
# 1  2018/12/27  271.00 -0.729980 -0.270020  272.00  272.50  270.25  64008.0
# 2  2018/12/26  271.75 -4.488281 -1.620117  272.75  274.00  270.75  70175.0
# 3  2018/12/24  276.25 -0.059998 -0.020004  274.75  277.00  274.25  46698.0
# 4  2018/12/21  276.50  0.150024  0.049988     NaN     NaN     NaN      NaN
#
#         거래대금       상장시가총액
# 0  1996651.0  922911424.0
# 1  2660684.0  917445376.0
# 2  2784379.0  920513728.0
# 3  2025262.0  934401856.0
# 4        NaN          NaN
# ┌▣ df.columns.to_list() ---- ---- ---- ----
# ['일자', '종가', '대비', '등락률', '시가', '고가', '저가', '거래량', '거래대금', '상장시가총액']

# %% [markdown]
# ## 전처리

# %%
# 컬럼명 변경하기
df_kip.rename(columns={"일자": "연_월_일", "대비":"종가_대비"}, inplace=True)
# 컬럼 순서
list_colOrder = ['연_월_일', '시가', '고가', '저가', '종가', "종가_대비","등락률", '거래량','거래대금', '상장시가총액']
df_kip = df_kip[list_colOrder]
df_kip.head(2)
# Out:
#         연_월_일     시가      고가      저가     종가     종가_대비       등락률      거래량  \
# 0  2018/12/28  261.5  262.75  261.25  262.0  1.410156  0.540039  62701.0
# 1  2018/12/27  261.5  261.75  259.75  260.5 -0.409912 -0.160034  84457.0
#
#         거래대금        상장시가총액
# 0  2895636.0  1.165450e+09
# 1  4081822.0  1.158683e+09

# %%
# 컬럼명 변경하기
df_keip.rename(columns={"일자": "연_월_일", "대비":"종가_대비"}, inplace=True)
# 컬럼 순서
list_colOrder = ['연_월_일', '시가', '고가', '저가', '종가', "종가_대비","등락률", '거래량','거래대금', '상장시가총액']
df_keip = df_keip[list_colOrder]
df_keip.head(2)
# Out:
#         연_월_일      시가      고가      저가      종가     종가_대비       등락률      거래량  \
# 0  2018/12/28  272.25  273.75  272.00  272.75  1.589844  0.589844  48040.0
# 1  2018/12/27  272.00  272.50  270.25  271.00 -0.729980 -0.270020  64008.0
#
#         거래대금       상장시가총액
# 0  1996651.0  922911424.0
# 1  2660684.0  917445376.0

# %% [markdown]
# ## 전처리 : MinMaxScaling

# %% [markdown]
# # df_ip0 : merge axis=0

# %%
df_kip_ = df_kip.copy()
df_keip_ = df_keip.copy()

df_kip_["주가지수명"] = "KRX_KOSPI200"
df_keip_["주가지수명"] = "KRX_KOSPI200ESG"

df_ip0 = pd.concat([df_kip_,  df_keip_])

df_ip0.sort_values(by =["연_월_일", "주가지수명"])
df_ip0
# Out:
#            연_월_일      시가      고가      저가       종가     종가_대비       등락률  \
# 0     2018/12/28  261.50  262.75  261.25  262.000  1.410156  0.540039
# 1     2018/12/27  261.50  261.75  259.75  260.500 -0.409912 -0.160034
# 2     2018/12/26  261.00  262.50  259.25  261.000 -3.470703 -1.309570
# 3     2018/12/24  263.50  265.00  263.00  264.500 -0.609863 -0.229980
# 4     2018/12/21  263.75  265.00  263.25  265.000  0.250000  0.090027
# ...          ...     ...     ...     ...      ...       ...       ...
# 1716  2012/01/06     NaN     NaN     NaN  240.500 -2.960938 -1.219727
# 1717  2012/01/05     NaN     NaN     NaN  243.500 -0.549805 -0.229980
# 1718  2012/01/04     NaN     NaN     NaN  244.125 -1.820312 -0.740234
# 1719  2012/01/03     NaN     NaN     NaN  245.875  7.191406  3.009766
# 1720  2012/01/02     NaN     NaN     NaN  238.750       NaN       NaN
#
#           거래량       거래대금        상장시가총액            주가지수명
# 0     62701.0  2895636.0  1.165450e+09     KRX_KOSPI200
# 1     84457.0  4081822.0  1.158683e+09     KRX_KOSPI200
# 2     92493.0  4372646.0  1.161841e+09     KRX_KOSPI200
# 3     61962.0  2930704.0  1.176009e+09     KRX_KOSPI200
# 4     92600.0  4430738.0  1.179096e+09     KRX_KOSPI200
# ...       ...        ...           ...              ...
# 1716      NaN        NaN           NaN  KRX_KOSPI200ESG
# 1717      NaN        NaN           NaN  KRX_KOSPI200ESG
# 1718      NaN        NaN           NaN  KRX_KOSPI200ESG
# 1719      NaN        NaN           NaN  KRX_KOSPI200ESG
# 1720      NaN        NaN           NaN  KRX_KOSPI200ESG
#
# [3941 rows x 11 columns]

# %% [markdown]
# ## 전처리

# %%
m.DerivedCol_Date(df_ip0, col_YMD="연_월_일", inplace=True)
# Out:
# inplace : True
#           연_월_일      시가      고가      저가       종가     종가_대비       등락률      거래량  \
# 0    2018-12-28  261.50  262.75  261.25  262.000  1.410156  0.540039  62701.0
# 1    2018-12-27  261.50  261.75  259.75  260.500 -0.409912 -0.160034  84457.0
# 2    2018-12-26  261.00  262.50  259.25  261.000 -3.470703 -1.309570  92493.0
# 3    2018-12-24  263.50  265.00  263.00  264.500 -0.609863 -0.229980  61962.0
# 4    2018-12-21  263.75  265.00  263.25  265.000  0.250000  0.090027  92600.0
# ...         ...     ...     ...     ...      ...       ...       ...      ...
# 1716 2012-01-06     NaN     NaN     NaN  240.500 -2.960938 -1.219727      NaN
# 1717 2012-01-05     NaN     NaN     NaN  243.500 -0.549805 -0.229980      NaN
# 1718 2012-01-04     NaN     NaN     NaN  244.125 -1.820312 -0.740234      NaN
# 1719 2012-01-03     NaN     NaN     NaN  245.875  7.191406  3.009766      NaN
# 1720 2012-01-02     NaN     NaN     NaN  238.750       NaN       NaN      NaN
#
#            거래대금        상장시가총액            주가지수명     연  분기   월    연_분기      연_월  \
# 0     2895636.0  1.165450e+09     KRX_KOSPI200  2018   4  12  2018-4  2018-12
# 1     4081822.0  1.158683e+09     KRX_KOSPI200  2018   4  12  2018-4  2018-12
# 2     4372646.0  1.161841e+09     KRX_KOSPI200  2018   4  12  2018-4  2018-12
# 3     2930704.0  1.176009e+09     KRX_KOSPI200  2018   4  12  2018-4  2018-12
# 4     4430738.0  1.179096e+09     KRX_KOSPI200  2018   4  12  2018-4  2018-12
# ...         ...           ...              ...   ...  ..  ..     ...      ...
# 1716        NaN           NaN  KRX_KOSPI200ESG  2012   1   1  2012-1   2012-1
# 1717        NaN           NaN  KRX_KOSPI200ESG  2012   1   1  2012-1   2012-1
# 1718        NaN           NaN  KRX_KOSPI200ESG  2012   1   1  2012-1   2012-1
# 1719        NaN           NaN  KRX_KOSPI200ESG  2012   1   1  2012-1   2012-1
# 1720        NaN           NaN  KRX_KOSPI200ESG  2012   1   1  2012-1   2012-1
#
#       분기_월     연_분기_월   일    월_일
# 0     4-12  2018-4-12  28  12-28
# 1     4-12  2018-4-12  27  12-27
# 2     4-12  2018-4-12  26  12-26
# 3     4-12  2018-4-12  24  12-24
# 4     4-12  2018-4-12  21  12-21
# ...    ...        ...  ..    ...
# 1716   1-1   2012-1-1   6    1-6
# 1717   1-1   2012-1-1   5    1-5
# 1718   1-1   2012-1-1   4    1-4
# 1719   1-1   2012-1-1   3    1-3
# 1720   1-1   2012-1-1   2    1-2
#
# [3941 rows x 20 columns]

# %% [markdown]
# ## 영속화

# %%
m.DfPrst(df_ip0, fp_ip0)
# Out:
# []

# %% [markdown]
# # df_ip1 : merge axis=1

# %%
df_ip1 = pd.merge(df_kip, df_keip, how="outer", on="연_월_일", suffixes=("KOSPI200", "_KOSPI200ESG"))
df_ip1.sort_values(by =["연_월_일"])
df_ip1
# Out:
#            연_월_일  시가KOSPI200  고가KOSPI200  저가KOSPI200  종가KOSPI200  \
# 0     2018/12/28     261.500     262.750     261.250     262.000
# 1     2018/12/27     261.500     261.750     259.750     260.500
# 2     2018/12/26     261.000     262.500     259.250     261.000
# 3     2018/12/24     263.500     265.000     263.000     264.500
# 4     2018/12/21     263.750     265.000     263.250     265.000
# ...          ...         ...         ...         ...         ...
# 2215  2010/01/08     222.625     222.750     219.125     222.625
# 2216  2010/01/07     224.250     224.750     221.250     221.250
# 2217  2010/01/06     223.875     225.000     223.500     224.625
# 2218  2010/01/05     224.250     224.375     222.125     222.875
# 2219  2010/01/04     221.625     223.500     221.625     223.500
#
#       종가_대비KOSPI200  등락률KOSPI200  거래량KOSPI200  거래대금KOSPI200  상장시가총액KOSPI200  \
# 0          1.410156     0.540039      62701.0     2895636.0    1.165450e+09
# 1         -0.409912    -0.160034      84457.0     4081822.0    1.158683e+09
# 2         -3.470703    -1.309570      92493.0     4372646.0    1.161841e+09
# 3         -0.609863    -0.229980      61962.0     2930704.0    1.176009e+09
# 4          0.250000     0.090027      92600.0     4430738.0    1.179096e+09
# ...             ...          ...          ...           ...             ...
# 2215       1.349609     0.609863     157255.0     5940569.0    7.750845e+08
# 2216      -3.359375    -1.500000     183417.0     6344257.0    7.702191e+08
# 2217       1.830078     0.819824     170500.0     5175271.0    7.810067e+08
# 2218      -0.649902    -0.290039     153282.0     5730882.0    7.742376e+08
# 2219       1.629883     0.729980      85967.0     3523480.0    7.770791e+08
#
#       시가_KOSPI200ESG  고가_KOSPI200ESG  저가_KOSPI200ESG  종가_KOSPI200ESG  \
# 0             272.25          273.75          272.00          272.75
# 1             272.00          272.50          270.25          271.00
# 2             272.75          274.00          270.75          271.75
# 3             274.75          277.00          274.25          276.25
# 4                NaN             NaN             NaN          276.50
# ...              ...             ...             ...             ...
# 2215             NaN             NaN             NaN             NaN
# 2216             NaN             NaN             NaN             NaN
# 2217             NaN             NaN             NaN             NaN
# 2218             NaN             NaN             NaN             NaN
# 2219             NaN             NaN             NaN             NaN
#
#       종가_대비_KOSPI200ESG  등락률_KOSPI200ESG  거래량_KOSPI200ESG  거래대금_KOSPI200ESG  \
# 0              1.589844         0.589844          48040.0         1996651.0
# 1             -0.729980        -0.270020          64008.0         2660684.0
# 2             -4.488281        -1.620117          70175.0         2784379.0
# 3             -0.059998        -0.020004          46698.0         2025262.0
# 4              0.150024         0.049988              NaN               NaN
# ...                 ...              ...              ...               ...
# 2215                NaN              NaN              NaN               NaN
# 2216                NaN              NaN              NaN               NaN
# 2217                NaN              NaN              NaN               NaN
# 2218                NaN              NaN              NaN               NaN
# 2219                NaN              NaN              NaN               NaN
#
#       상장시가총액_KOSPI200ESG
# 0            922911424.0
# 1            917445376.0
# 2            920513728.0
# 3            934401856.0
# 4                    NaN
# ...                  ...
# 2215                 NaN
# 2216                 NaN
# 2217                 NaN
# 2218                 NaN
# 2219                 NaN
#
# [2220 rows x 19 columns]

# %% [markdown]
# ## 전처리

# %%
m.DerivedCol_Date(df_ip1, col_YMD="연_월_일", inplace=True)
# Out:
# inplace : True
#           연_월_일  시가KOSPI200  고가KOSPI200  저가KOSPI200  종가KOSPI200  \
# 0    2018-12-28     261.500     262.750     261.250     262.000
# 1    2018-12-27     261.500     261.750     259.750     260.500
# 2    2018-12-26     261.000     262.500     259.250     261.000
# 3    2018-12-24     263.500     265.000     263.000     264.500
# 4    2018-12-21     263.750     265.000     263.250     265.000
# ...         ...         ...         ...         ...         ...
# 2215 2010-01-08     222.625     222.750     219.125     222.625
# 2216 2010-01-07     224.250     224.750     221.250     221.250
# 2217 2010-01-06     223.875     225.000     223.500     224.625
# 2218 2010-01-05     224.250     224.375     222.125     222.875
# 2219 2010-01-04     221.625     223.500     221.625     223.500
#
#       종가_대비KOSPI200  등락률KOSPI200  거래량KOSPI200  거래대금KOSPI200  상장시가총액KOSPI200  \
# 0          1.410156     0.540039      62701.0     2895636.0    1.165450e+09
# 1         -0.409912    -0.160034      84457.0     4081822.0    1.158683e+09
# 2         -3.470703    -1.309570      92493.0     4372646.0    1.161841e+09
# 3         -0.609863    -0.229980      61962.0     2930704.0    1.176009e+09
# 4          0.250000     0.090027      92600.0     4430738.0    1.179096e+09
# ...             ...          ...          ...           ...             ...
# 2215       1.349609     0.609863     157255.0     5940569.0    7.750845e+08
# 2216      -3.359375    -1.500000     183417.0     6344257.0    7.702191e+08
# 2217       1.830078     0.819824     170500.0     5175271.0    7.810067e+08
# 2218      -0.649902    -0.290039     153282.0     5730882.0    7.742376e+08
# 2219       1.629883     0.729980      85967.0     3523480.0    7.770791e+08
#
#       시가_KOSPI200ESG  고가_KOSPI200ESG  저가_KOSPI200ESG  종가_KOSPI200ESG  \
# 0             272.25          273.75          272.00          272.75
# 1             272.00          272.50          270.25          271.00
# 2             272.75          274.00          270.75          271.75
# 3             274.75          277.00          274.25          276.25
# 4                NaN             NaN             NaN          276.50
# ...              ...             ...             ...             ...
# 2215             NaN             NaN             NaN             NaN
# 2216             NaN             NaN             NaN             NaN
# 2217             NaN             NaN             NaN             NaN
# 2218             NaN             NaN             NaN             NaN
# 2219             NaN             NaN             NaN             NaN
#
#       종가_대비_KOSPI200ESG  등락률_KOSPI200ESG  거래량_KOSPI200ESG  거래대금_KOSPI200ESG  \
# 0              1.589844         0.589844          48040.0         1996651.0
# 1             -0.729980        -0.270020          64008.0         2660684.0
# 2             -4.488281        -1.620117          70175.0         2784379.0
# 3             -0.059998        -0.020004          46698.0         2025262.0
# 4              0.150024         0.049988              NaN               NaN
# ...                 ...              ...              ...               ...
# 2215                NaN              NaN              NaN               NaN
# 2216                NaN              NaN              NaN               NaN
# 2217                NaN              NaN              NaN               NaN
# 2218                NaN              NaN              NaN               NaN
# 2219                NaN              NaN              NaN               NaN
#
#       상장시가총액_KOSPI200ESG     연  분기   월    연_분기      연_월  분기_월     연_분기_월   일  \
# 0            922911424.0  2018   4  12  2018-4  2018-12  4-12  2018-4-12  28
# 1            917445376.0  2018   4  12  2018-4  2018-12  4-12  2018-4-12  27
# 2            920513728.0  2018   4  12  2018-4  2018-12  4-12  2018-4-12  26
# 3            934401856.0  2018   4  12  2018-4  2018-12  4-12  2018-4-12  24
# 4                    NaN  2018   4  12  2018-4  2018-12  4-12  2018-4-12  21
# ...                  ...   ...  ..  ..     ...      ...   ...        ...  ..
# 2215                 NaN  2010   1   1  2010-1   2010-1   1-1   2010-1-1   8
# 2216                 NaN  2010   1   1  2010-1   2010-1   1-1   2010-1-1   7
# 2217                 NaN  2010   1   1  2010-1   2010-1   1-1   2010-1-1   6
# 2218                 NaN  2010   1   1  2010-1   2010-1   1-1   2010-1-1   5
# 2219                 NaN  2010   1   1  2010-1   2010-1   1-1   2010-1-1   4
#
#         월_일
# 0     12-28
# 1     12-27
# 2     12-26
# 3     12-24
# 4     12-21
# ...     ...
# 2215    1-8
# 2216    1-7
# 2217    1-6
# 2218    1-5
# 2219    1-4
#
# [2220 rows x 28 columns]

# %% [markdown]
# ## 영속화

# %%
m.DfPrst(df_ip1, fp_ip1)
# Out:
# ['../data/indexPrice.parquet']
